# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from datetime import date
from scipy.stats import linregress
import pprint as pp


# Import API key
from api_key import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
pd.read_csv(output_data_file)
# Out:
#      Unnamed: 0              0
# 0             0          seoul
# 1             1        qaanaaq
# 2             2  belushya guba
# 3             3    mys shmidta
# 4             4        maniago
# ..          ...            ...
# 622         622        butembo
# 623         623       necochea
# 624         624     oranjemund
# 625         625         mtwara
# 626         626        awjilah
#
# [627 rows x 2 columns]

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities_df=pd.DataFrame(cities)
cities_df.to_csv(output_data_file)
cities_df=cities_df.rename(columns={0:"City"})

cities_df["Cloudiness"]=""
cities_df["Country"]=""
cities_df["Date"]=""
cities_df["Humidity"]=""
cities_df["Lat"]=""
cities_df["Long"]=""
cities_df["Max Temp"]=""
cities_df["Wind Speed"]=""

cities_df
# Out:
#                City Cloudiness Country Date Humidity Lat Long Max Temp  \
# 0    saint-philippe
# 1           ushuaia
# 2           ahipara
# 3      saint-gilles
# 4              zima
# ..              ...        ...     ...  ...      ...  ..  ...      ...
# 599          khonsa
# 600          tsogni
# 601        yairipok
# 602       babanusah
# 603         corinto
#
#     Wind Speed
# 0
# 1
# 2
# 3
# 4
# ..         ...
# 599
# 600
# 601
# 602
# 603
#
# [604 rows x 9 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "https://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key

# %%
print(requests.get(base_url + '&q=' + 'new york' + '&units=imperial').json())
# Out:
# {'coord': {'lon': -74.006, 'lat': 40.7143}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 53.6, 'feels_like': 46.62, 'temp_min': 53.6, 'temp_max': 53.6, 'pressure': 1018, 'humidity': 26}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 0}, 'clouds': {'all': 1}, 'dt': 1615614656, 'sys': {'type': 1, 'id': 4610, 'country': 'US', 'sunrise': 1615633838, 'sunset': 1615676422}, 'timezone': -18000, 'id': 5128581, 'name': 'New York', 'cod': 200}

# %%
temp=[]

record=1
sets=1



print("Beginning Data Retrieval")
print("-----------------------------")

for index, row in cities_df.iterrows():
    city = row['City']
    
    if (record%50)==0:
        record=1
        sets +=1
    else:
        record+=1 
    response = requests.get(query_url + city).json()
    print(f"Processing Record {record-1} of Set {sets} | {city} ")
    
    if response["cod"]!="404" and response["cod"]!="500" :
        cities_df.loc[index, "Cloudiness"]=response["clouds"]["all"]
        cities_df.loc[index, "Country"]=response["sys"]["country"]
        current_date=datetime.datetime.fromtimestamp(response["dt"]).strftime("%x")
        cities_df.loc[index, "Date"]=response["dt"]
        cities_df.loc[index, "Humidity"]=response["main"]["humidity"]
        cities_df.loc[index, "Lat"]=float(response["coord"]["lat"])
        cities_df.loc[index, "Long"]=response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"]=float(response["main"]["temp_max"])
        cities_df.loc[index, "Wind Speed"]=response["wind"]["speed"]
    else:
        print("City Not Found")
    
print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | ahipara
# Processing Record 4 of Set 1 | saint-gilles
# Processing Record 5 of Set 1 | zima
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | oliveira
# Processing Record 10 of Set 1 | vangaindrano
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | anadyr
# Processing Record 13 of Set 1 | saint-joseph
# Processing Record 14 of Set 1 | umzimvubu
# City Not Found
# Processing Record 15 of Set 1 | nishihara
# Processing Record 16 of Set 1 | dawei
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | ponta do sol
# Processing Record 19 of Set 1 | tawzar
# City Not Found
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | mys shmidta
# City Not Found
# Processing Record 25 of Set 1 | dera din panah
# City Not Found
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | praia da vitoria
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | kiama
# Processing Record 31 of Set 1 | warrensburg
# Processing Record 32 of Set 1 | taolanaro
# City Not Found
# Processing Record 33 of Set 1 | pindiga
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | acapulco
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | hay river
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | fairbanks
# Processing Record 41 of Set 1 | kalmunai
# Processing Record 42 of Set 1 | umkomaas
# Processing Record 43 of Set 1 | barentsburg
# City Not Found
# Processing Record 44 of Set 1 | aksu
# Processing Record 45 of Set 1 | huntingdon
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | tuatapere
# Processing Record 48 of Set 1 | luderitz
# Processing Record 49 of Set 1 | east london
# Processing Record 0 of Set 2 | tsihombe
# City Not Found
# Processing Record 1 of Set 2 | san vicente
# Processing Record 2 of Set 2 | chengde
# Processing Record 3 of Set 2 | tutova
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | urfa
# City Not Found
# Processing Record 6 of Set 2 | vaitupu
# City Not Found
# Processing Record 7 of Set 2 | mulki
# Processing Record 8 of Set 2 | meridian
# Processing Record 9 of Set 2 | christchurch
# Processing Record 10 of Set 2 | okha
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | vila velha
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | nago
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | sao jose da coroa grande
# Processing Record 20 of Set 2 | alice springs
# Processing Record 21 of Set 2 | beloha
# Processing Record 22 of Set 2 | kawalu
# Processing Record 23 of Set 2 | wanning
# Processing Record 24 of Set 2 | ocampo
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | provideniya
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | auki
# Processing Record 29 of Set 2 | brae
# Processing Record 30 of Set 2 | zhuhai
# Processing Record 31 of Set 2 | saint-francois
# Processing Record 32 of Set 2 | yulara
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | bundaberg
# Processing Record 35 of Set 2 | lewistown
# Processing Record 36 of Set 2 | rio grande
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | balabac
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | jiuquan
# Processing Record 42 of Set 2 | skibbereen
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | siquirres
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | genhe
# Processing Record 47 of Set 2 | mahendragarh
# Processing Record 48 of Set 2 | prince rupert
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 0 of Set 3 | komsomolskiy
# Processing Record 1 of Set 3 | dudinka
# Processing Record 2 of Set 3 | sampit
# Processing Record 3 of Set 3 | vao
# Processing Record 4 of Set 3 | garissa
# Processing Record 5 of Set 3 | narsaq
# Processing Record 6 of Set 3 | wloclawek
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | talcahuano
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | te anau
# Processing Record 14 of Set 3 | northam
# Processing Record 15 of Set 3 | morant bay
# Processing Record 16 of Set 3 | karamea
# City Not Found
# Processing Record 17 of Set 3 | lompoc
# Processing Record 18 of Set 3 | lorengau
# Processing Record 19 of Set 3 | haines junction
# Processing Record 20 of Set 3 | nyurba
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | ixtapa
# Processing Record 23 of Set 3 | bargal
# City Not Found
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | amderma
# City Not Found
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | ancud
# Processing Record 28 of Set 3 | sataua
# City Not Found
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | beba
# Processing Record 31 of Set 3 | tezu
# Processing Record 32 of Set 3 | itaueira
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | sibolga
# Processing Record 35 of Set 3 | belushya guba
# City Not Found
# Processing Record 36 of Set 3 | gat
# Processing Record 37 of Set 3 | touros
# Processing Record 38 of Set 3 | katobu
# Processing Record 39 of Set 3 | tessalit
# Processing Record 40 of Set 3 | eufaula
# Processing Record 41 of Set 3 | aleksandrov gay
# Processing Record 42 of Set 3 | cranbrook
# Processing Record 43 of Set 3 | filadelfia
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | ribeira grande
# Processing Record 46 of Set 3 | tazmalt
# Processing Record 47 of Set 3 | mataura
# Processing Record 48 of Set 3 | nogliki
# Processing Record 49 of Set 3 | henties bay
# Processing Record 0 of Set 4 | dingle
# Processing Record 1 of Set 4 | redlands
# Processing Record 2 of Set 4 | lincoln
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | toftir
# City Not Found
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | otane
# Processing Record 7 of Set 4 | iqaluit
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | kumluca
# Processing Record 10 of Set 4 | kavaratti
# Processing Record 11 of Set 4 | porbandar
# Processing Record 12 of Set 4 | las vegas
# Processing Record 13 of Set 4 | semnan
# Processing Record 14 of Set 4 | fort saint john
# City Not Found
# Processing Record 15 of Set 4 | santa vitoria do palmar
# Processing Record 16 of Set 4 | phan rang
# City Not Found
# Processing Record 17 of Set 4 | ulaangom
# Processing Record 18 of Set 4 | bubaque
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | qaanaaq
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | saint-augustin
# Processing Record 23 of Set 4 | shizuishan
# Processing Record 24 of Set 4 | omboue
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | esso
# Processing Record 27 of Set 4 | vostok
# Processing Record 28 of Set 4 | sentyabrskiy
# City Not Found
# Processing Record 29 of Set 4 | valparaiso
# Processing Record 30 of Set 4 | conakry
# Processing Record 31 of Set 4 | acucena
# Processing Record 32 of Set 4 | gizo
# Processing Record 33 of Set 4 | zeya
# Processing Record 34 of Set 4 | nizhneyansk
# City Not Found
# Processing Record 35 of Set 4 | saleaula
# City Not Found
# Processing Record 36 of Set 4 | oistins
# Processing Record 37 of Set 4 | dabola
# Processing Record 38 of Set 4 | vestmanna
# Processing Record 39 of Set 4 | ijaki
# City Not Found
# Processing Record 40 of Set 4 | port lincoln
# Processing Record 41 of Set 4 | coahuayana
# Processing Record 42 of Set 4 | wahran
# City Not Found
# Processing Record 43 of Set 4 | mayumba
# Processing Record 44 of Set 4 | thompson
# Processing Record 45 of Set 4 | chimbote
# Processing Record 46 of Set 4 | sidvokodvo
# Processing Record 47 of Set 4 | atar
# Processing Record 48 of Set 4 | itoman
# Processing Record 49 of Set 4 | caravelas
# Processing Record 0 of Set 5 | constitucion
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | quatre cocos
# Processing Record 3 of Set 5 | norman wells
# Processing Record 4 of Set 5 | chagda
# City Not Found
# Processing Record 5 of Set 5 | beringovskiy
# Processing Record 6 of Set 5 | benjamin aceval
# Processing Record 7 of Set 5 | umm kaddadah
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | aklavik
# Processing Record 10 of Set 5 | beaverlodge
# Processing Record 11 of Set 5 | pocoes
# Processing Record 12 of Set 5 | attawapiskat
# City Not Found
# Processing Record 13 of Set 5 | nguiu
# City Not Found
# Processing Record 14 of Set 5 | kahului
# Processing Record 15 of Set 5 | yar-sale
# Processing Record 16 of Set 5 | kamaishi
# Processing Record 17 of Set 5 | alofi
# Processing Record 18 of Set 5 | hasaki
# Processing Record 19 of Set 5 | oum hadjer
# Processing Record 20 of Set 5 | la macarena
# Processing Record 21 of Set 5 | finschhafen
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | chapais
# Processing Record 24 of Set 5 | karauzyak
# City Not Found
# Processing Record 25 of Set 5 | college
# Processing Record 26 of Set 5 | mackay
# Processing Record 27 of Set 5 | ob
# City Not Found
# Processing Record 28 of Set 5 | mount gambier
# Processing Record 29 of Set 5 | kajaani
# Processing Record 30 of Set 5 | kenai
# Processing Record 31 of Set 5 | marsa matruh
# Processing Record 32 of Set 5 | shelburne
# Processing Record 33 of Set 5 | pleasanton
# Processing Record 34 of Set 5 | lloydminster
# Processing Record 35 of Set 5 | wulanhaote
# City Not Found
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | sorvag
# City Not Found
# Processing Record 38 of Set 5 | ostrovnoy
# Processing Record 39 of Set 5 | nanortalik
# Processing Record 40 of Set 5 | formoso do araguaia
# City Not Found
# Processing Record 41 of Set 5 | souillac
# Processing Record 42 of Set 5 | tiksi
# Processing Record 43 of Set 5 | hjelset
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | santa eulalia del rio
# City Not Found
# Processing Record 46 of Set 5 | la paz
# Processing Record 47 of Set 5 | berlevag
# Processing Record 48 of Set 5 | sitka
# Processing Record 49 of Set 5 | pascagoula
# Processing Record 0 of Set 6 | hervey bay
# Processing Record 1 of Set 6 | palmer
# Processing Record 2 of Set 6 | beyneu
# Processing Record 3 of Set 6 | yellowknife
# Processing Record 4 of Set 6 | kudahuvadhoo
# Processing Record 5 of Set 6 | icod de los vinos
# Processing Record 6 of Set 6 | pangody
# Processing Record 7 of Set 6 | tidore
# City Not Found
# Processing Record 8 of Set 6 | sao filipe
# Processing Record 9 of Set 6 | bathsheba
# Processing Record 10 of Set 6 | vygonichi
# Processing Record 11 of Set 6 | lata
# Processing Record 12 of Set 6 | mahibadhoo
# Processing Record 13 of Set 6 | illoqqortoormiut
# City Not Found
# Processing Record 14 of Set 6 | uige
# Processing Record 15 of Set 6 | ballina
# Processing Record 16 of Set 6 | barcelos
# Processing Record 17 of Set 6 | ilulissat
# Processing Record 18 of Set 6 | tottori
# Processing Record 19 of Set 6 | saldanha
# Processing Record 20 of Set 6 | marcona
# City Not Found
# Processing Record 21 of Set 6 | bethel
# Processing Record 22 of Set 6 | medicine hat
# Processing Record 23 of Set 6 | kazalinsk
# City Not Found
# Processing Record 24 of Set 6 | pionerskiy
# Processing Record 25 of Set 6 | mount isa
# Processing Record 26 of Set 6 | clyde river
# Processing Record 27 of Set 6 | khormuj
# City Not Found
# Processing Record 28 of Set 6 | udimskiy
# Processing Record 29 of Set 6 | merauke
# Processing Record 30 of Set 6 | fougamou
# Processing Record 31 of Set 6 | dunedin
# Processing Record 32 of Set 6 | daru
# Processing Record 33 of Set 6 | wewak
# Processing Record 34 of Set 6 | verkhoyansk
# Processing Record 35 of Set 6 | namibe
# Processing Record 36 of Set 6 | ilhabela
# Processing Record 37 of Set 6 | garoua
# Processing Record 38 of Set 6 | nelson bay
# Processing Record 39 of Set 6 | hambantota
# Processing Record 40 of Set 6 | bilma
# Processing Record 41 of Set 6 | meyungs
# City Not Found
# Processing Record 42 of Set 6 | sorland
# Processing Record 43 of Set 6 | san quintin
# Processing Record 44 of Set 6 | jinchang
# Processing Record 45 of Set 6 | havoysund
# Processing Record 46 of Set 6 | pachino
# Processing Record 47 of Set 6 | podstepki
# Processing Record 48 of Set 6 | ajuchitlan
# Processing Record 49 of Set 6 | matadi
# Processing Record 0 of Set 7 | birao
# Processing Record 1 of Set 7 | san ramon
# Processing Record 2 of Set 7 | calgary
# Processing Record 3 of Set 7 | tay ninh
# Processing Record 4 of Set 7 | merida
# Processing Record 5 of Set 7 | larreynaga
# Processing Record 6 of Set 7 | susangerd
# Processing Record 7 of Set 7 | lolua
# City Not Found
# Processing Record 8 of Set 7 | cajueiro
# Processing Record 9 of Set 7 | sioux lookout
# Processing Record 10 of Set 7 | grindavik
# Processing Record 11 of Set 7 | olhao
# Processing Record 12 of Set 7 | kismayo
# Processing Record 13 of Set 7 | risor
# Processing Record 14 of Set 7 | ginda
# Processing Record 15 of Set 7 | arman
# Processing Record 16 of Set 7 | makushino
# Processing Record 17 of Set 7 | miramar
# Processing Record 18 of Set 7 | mocambique
# City Not Found
# Processing Record 19 of Set 7 | mmathubudukwane
# Processing Record 20 of Set 7 | san lawrenz
# Processing Record 21 of Set 7 | tilichiki
# Processing Record 22 of Set 7 | fortuna
# Processing Record 23 of Set 7 | dedougou
# Processing Record 24 of Set 7 | hobyo
# Processing Record 25 of Set 7 | dungarpur
# Processing Record 26 of Set 7 | srednekolymsk
# Processing Record 27 of Set 7 | buraydah
# Processing Record 28 of Set 7 | meulaboh
# Processing Record 29 of Set 7 | meadow lake
# Processing Record 30 of Set 7 | roald
# Processing Record 31 of Set 7 | garowe
# Processing Record 32 of Set 7 | mogapi
# Processing Record 33 of Set 7 | suamico
# Processing Record 34 of Set 7 | tupik
# Processing Record 35 of Set 7 | magadan
# Processing Record 36 of Set 7 | ulaanbaatar
# Processing Record 37 of Set 7 | taman
# Processing Record 38 of Set 7 | westport
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | mopti
# Processing Record 41 of Set 7 | taltal
# Processing Record 42 of Set 7 | nantucket
# Processing Record 43 of Set 7 | iracoubo
# Processing Record 44 of Set 7 | dzhebariki-khaya
# Processing Record 45 of Set 7 | sao felix do xingu
# Processing Record 46 of Set 7 | aykhal
# Processing Record 47 of Set 7 | alindao
# Processing Record 48 of Set 7 | tumannyy
# City Not Found
# Processing Record 49 of Set 7 | port hardy
# Processing Record 0 of Set 8 | pen
# Processing Record 1 of Set 8 | victoria
# Processing Record 2 of Set 8 | ampanihy
# Processing Record 3 of Set 8 | tarrafal
# Processing Record 4 of Set 8 | grand centre
# City Not Found
# Processing Record 5 of Set 8 | mbandaka
# Processing Record 6 of Set 8 | axim
# Processing Record 7 of Set 8 | umm ruwabah
# City Not Found
# Processing Record 8 of Set 8 | malanje
# Processing Record 9 of Set 8 | plavsk
# Processing Record 10 of Set 8 | pacific grove
# Processing Record 11 of Set 8 | qasigiannguit
# Processing Record 12 of Set 8 | waw
# Processing Record 13 of Set 8 | angoram
# Processing Record 14 of Set 8 | machali
# Processing Record 15 of Set 8 | kpandu
# Processing Record 16 of Set 8 | nouadhibou
# Processing Record 17 of Set 8 | samusu
# City Not Found
# Processing Record 18 of Set 8 | vanimo
# Processing Record 19 of Set 8 | fort nelson
# Processing Record 20 of Set 8 | mehamn
# Processing Record 21 of Set 8 | santa maria
# Processing Record 22 of Set 8 | tombouctou
# Processing Record 23 of Set 8 | tura
# Processing Record 24 of Set 8 | broken hill
# Processing Record 25 of Set 8 | lasa
# Processing Record 26 of Set 8 | vestmannaeyjar
# Processing Record 27 of Set 8 | dukat
# Processing Record 28 of Set 8 | kyra
# Processing Record 29 of Set 8 | bondo
# Processing Record 30 of Set 8 | pevek
# Processing Record 31 of Set 8 | xining
# Processing Record 32 of Set 8 | khash
# Processing Record 33 of Set 8 | mabaruma
# Processing Record 34 of Set 8 | belmonte
# Processing Record 35 of Set 8 | shingu
# Processing Record 36 of Set 8 | kaspiyskiy
# Processing Record 37 of Set 8 | avera
# Processing Record 38 of Set 8 | cockburn town
# Processing Record 39 of Set 8 | mercedes
# Processing Record 40 of Set 8 | adrar
# Processing Record 41 of Set 8 | camopi
# Processing Record 42 of Set 8 | san andres
# Processing Record 43 of Set 8 | pokrovsk-uralskiy
# City Not Found
# Processing Record 44 of Set 8 | kyshtovka
# Processing Record 45 of Set 8 | moranbah
# Processing Record 46 of Set 8 | arequipa
# Processing Record 47 of Set 8 | gombong
# Processing Record 48 of Set 8 | guajara-mirim
# City Not Found
# Processing Record 49 of Set 8 | tzaneen
# Processing Record 0 of Set 9 | leningradskiy
# Processing Record 1 of Set 9 | juybar
# Processing Record 2 of Set 9 | kununurra
# Processing Record 3 of Set 9 | olinda
# Processing Record 4 of Set 9 | bamako
# Processing Record 5 of Set 9 | amga
# Processing Record 6 of Set 9 | faya
# Processing Record 7 of Set 9 | champerico
# Processing Record 8 of Set 9 | la ronge
# Processing Record 9 of Set 9 | conceicao da barra
# Processing Record 10 of Set 9 | takob
# City Not Found
# Processing Record 11 of Set 9 | ndele
# Processing Record 12 of Set 9 | natchez
# Processing Record 13 of Set 9 | bandarbeyla
# Processing Record 14 of Set 9 | camacari
# Processing Record 15 of Set 9 | paysandu
# Processing Record 16 of Set 9 | faanui
# Processing Record 17 of Set 9 | coquimbo
# Processing Record 18 of Set 9 | funtua
# Processing Record 19 of Set 9 | port augusta
# Processing Record 20 of Set 9 | alihe
# Processing Record 21 of Set 9 | pirgos
# Processing Record 22 of Set 9 | punta alta
# Processing Record 23 of Set 9 | turka
# Processing Record 24 of Set 9 | chunskiy
# Processing Record 25 of Set 9 | cidreira
# Processing Record 26 of Set 9 | portoferraio
# Processing Record 27 of Set 9 | vakhrushev
# Processing Record 28 of Set 9 | klaksvik
# Processing Record 29 of Set 9 | jacqueville
# Processing Record 30 of Set 9 | nome
# Processing Record 31 of Set 9 | mecca
# Processing Record 32 of Set 9 | moree
# Processing Record 33 of Set 9 | lexington
# Processing Record 34 of Set 9 | soe
# Processing Record 35 of Set 9 | solnechnyy
# Processing Record 36 of Set 9 | langarud
# Processing Record 37 of Set 9 | juneau
# Processing Record 38 of Set 9 | isiro
# Processing Record 39 of Set 9 | diamantino
# Processing Record 40 of Set 9 | chumikan
# Processing Record 41 of Set 9 | lebu
# Processing Record 42 of Set 9 | cabedelo
# Processing Record 43 of Set 9 | naze
# Processing Record 44 of Set 9 | caidian
# Processing Record 45 of Set 9 | morden
# Processing Record 46 of Set 9 | te karaka
# Processing Record 47 of Set 9 | yamada
# Processing Record 48 of Set 9 | tabalosos
# Processing Record 49 of Set 9 | nanzhang
# Processing Record 0 of Set 10 | moron
# Processing Record 1 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 10 | ust-nera
# Processing Record 3 of Set 10 | tabuk
# Processing Record 4 of Set 10 | boddam
# Processing Record 5 of Set 10 | codrington
# Processing Record 6 of Set 10 | yilan
# Processing Record 7 of Set 10 | padang
# Processing Record 8 of Set 10 | camacha
# Processing Record 9 of Set 10 | inderborskiy
# City Not Found
# Processing Record 10 of Set 10 | tautira
# Processing Record 11 of Set 10 | yuty
# Processing Record 12 of Set 10 | bulgan
# Processing Record 13 of Set 10 | airai
# Processing Record 14 of Set 10 | egvekinot
# Processing Record 15 of Set 10 | wahiawa
# Processing Record 16 of Set 10 | bima
# Processing Record 17 of Set 10 | lavrentiya
# Processing Record 18 of Set 10 | san miguel
# Processing Record 19 of Set 10 | santiago
# Processing Record 20 of Set 10 | comandau
# Processing Record 21 of Set 10 | ukiah
# Processing Record 22 of Set 10 | cayenne
# Processing Record 23 of Set 10 | gangotri
# City Not Found
# Processing Record 24 of Set 10 | tambo grande
# Processing Record 25 of Set 10 | nabire
# Processing Record 26 of Set 10 | puerto del rosario
# Processing Record 27 of Set 10 | manoel urbano
# Processing Record 28 of Set 10 | broome
# Processing Record 29 of Set 10 | byron bay
# Processing Record 30 of Set 10 | puerto salgar
# Processing Record 31 of Set 10 | zulueta
# Processing Record 32 of Set 10 | moroni
# Processing Record 33 of Set 10 | lagoa
# Processing Record 34 of Set 10 | kosh-agach
# Processing Record 35 of Set 10 | vrangel
# Processing Record 36 of Set 10 | seoul
# Processing Record 37 of Set 10 | eldikan
# City Not Found
# Processing Record 38 of Set 10 | katsuura
# Processing Record 39 of Set 10 | ndouci
# City Not Found
# Processing Record 40 of Set 10 | bonavista
# Processing Record 41 of Set 10 | japura
# Processing Record 42 of Set 10 | nuuk
# Processing Record 43 of Set 10 | palabuhanratu
# City Not Found
# Processing Record 44 of Set 10 | koryukivka
# Processing Record 45 of Set 10 | huilong
# Processing Record 46 of Set 10 | grand river south east
# City Not Found
# Processing Record 47 of Set 10 | idlib
# Processing Record 48 of Set 10 | hami
# Processing Record 49 of Set 10 | tapaua
# City Not Found
# Processing Record 0 of Set 11 | abnub
# Processing Record 1 of Set 11 | aswan
# Processing Record 2 of Set 11 | qaqortoq
# Processing Record 3 of Set 11 | fort frances
# Processing Record 4 of Set 11 | temozon
# Processing Record 5 of Set 11 | port hawkesbury
# Processing Record 6 of Set 11 | magalia
# Processing Record 7 of Set 11 | fare
# Processing Record 8 of Set 11 | jasper
# Processing Record 9 of Set 11 | lancaster
# Processing Record 10 of Set 11 | ambalavao
# Processing Record 11 of Set 11 | visnes
# Processing Record 12 of Set 11 | muros
# Processing Record 13 of Set 11 | cody
# Processing Record 14 of Set 11 | isangel
# Processing Record 15 of Set 11 | ewa beach
# Processing Record 16 of Set 11 | mweka
# Processing Record 17 of Set 11 | houma
# Processing Record 18 of Set 11 | becerril
# Processing Record 19 of Set 11 | zhigalovo
# Processing Record 20 of Set 11 | namatanai
# Processing Record 21 of Set 11 | tshikapa
# Processing Record 22 of Set 11 | krasnoselkup
# Processing Record 23 of Set 11 | nava
# Processing Record 24 of Set 11 | jumla
# Processing Record 25 of Set 11 | islahiye
# Processing Record 26 of Set 11 | carauari
# Processing Record 27 of Set 11 | rakaia
# Processing Record 28 of Set 11 | ketchikan
# Processing Record 29 of Set 11 | tomatlan
# Processing Record 30 of Set 11 | calamar
# Processing Record 31 of Set 11 | yenagoa
# Processing Record 32 of Set 11 | matay
# Processing Record 33 of Set 11 | viedma
# Processing Record 34 of Set 11 | barstow
# Processing Record 35 of Set 11 | sandnessjoen
# Processing Record 36 of Set 11 | chikoy
# City Not Found
# Processing Record 37 of Set 11 | ambulu
# Processing Record 38 of Set 11 | whitehorse
# Processing Record 39 of Set 11 | vardo
# Processing Record 40 of Set 11 | sur
# Processing Record 41 of Set 11 | barranca
# Processing Record 42 of Set 11 | wattegama
# Processing Record 43 of Set 11 | malartic
# Processing Record 44 of Set 11 | kizner
# Processing Record 45 of Set 11 | tabiauea
# City Not Found
# Processing Record 46 of Set 11 | saintes
# Processing Record 47 of Set 11 | mao
# Processing Record 48 of Set 11 | nsukka
# Processing Record 49 of Set 11 | ola
# Processing Record 0 of Set 12 | port hedland
# Processing Record 1 of Set 12 | homer
# Processing Record 2 of Set 12 | burnie
# Processing Record 3 of Set 12 | rognan
# Processing Record 4 of Set 12 | biak
# Processing Record 5 of Set 12 | guerrero negro
# Processing Record 6 of Set 12 | sistranda
# Processing Record 7 of Set 12 | zalantun
# Processing Record 8 of Set 12 | qui nhon
# Processing Record 9 of Set 12 | falmouth
# Processing Record 10 of Set 12 | warwick
# Processing Record 11 of Set 12 | corn island
# Processing Record 12 of Set 12 | conceicao do araguaia
# Processing Record 13 of Set 12 | kamariotissa
# Processing Record 14 of Set 12 | taubate
# Processing Record 15 of Set 12 | eyl
# Processing Record 16 of Set 12 | acajutla
# Processing Record 17 of Set 12 | baruun-urt
# Processing Record 18 of Set 12 | qinnan
# Processing Record 19 of Set 12 | van
# Processing Record 20 of Set 12 | senneterre
# Processing Record 21 of Set 12 | eatonton
# Processing Record 22 of Set 12 | rolla
# Processing Record 23 of Set 12 | kushiro
# Processing Record 24 of Set 12 | cap malheureux
# Processing Record 25 of Set 12 | pakala
# Processing Record 26 of Set 12 | patrai
# City Not Found
# Processing Record 27 of Set 12 | kanelovskaya
# Processing Record 28 of Set 12 | sambava
# Processing Record 29 of Set 12 | kamenskoye
# City Not Found
# Processing Record 30 of Set 12 | caraquet
# Processing Record 31 of Set 12 | margate
# Processing Record 32 of Set 12 | roma
# Processing Record 33 of Set 12 | goderich
# Processing Record 34 of Set 12 | jalu
# Processing Record 35 of Set 12 | virden
# Processing Record 36 of Set 12 | nador
# Processing Record 37 of Set 12 | tual
# Processing Record 38 of Set 12 | liuli
# Processing Record 39 of Set 12 | lazaro cardenas
# Processing Record 40 of Set 12 | rawson
# Processing Record 41 of Set 12 | heihe
# Processing Record 42 of Set 12 | glubokoe
# City Not Found
# Processing Record 43 of Set 12 | lesnoye
# Processing Record 44 of Set 12 | sao joao
# Processing Record 45 of Set 12 | sochaczew
# Processing Record 46 of Set 12 | xuzhou
# Processing Record 47 of Set 12 | fort-shevchenko
# Processing Record 48 of Set 12 | dzhusaly
# City Not Found
# Processing Record 49 of Set 12 | tucupita
# Processing Record 0 of Set 13 | khonsa
# Processing Record 1 of Set 13 | tsogni
# Processing Record 2 of Set 13 | yairipok
# Processing Record 3 of Set 13 | babanusah
# City Not Found
# Processing Record 4 of Set 13 | corinto
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# Convert Raw Data to DataFrame
# Export the city data into a .csv.
# Display the DataFrame

# %%
cities_df.head()
# Out:
#              City Cloudiness Country        Date Humidity      Lat     Long  \
# 0  saint-philippe         90      RE  1615615211       65 -21.3585  55.7679
# 1         ushuaia         75      AR  1615615214       93    -54.8    -68.3
# 2         ahipara         59      NZ  1615615216       85 -35.1667  173.167
# 3    saint-gilles          0      FR  1615615216       81  43.6766   4.4302
# 4            zima         93      RU  1615615216       96  53.9202  102.044
#
#   Max Temp Wind Speed
# 0     84.2      20.71
# 1       41      43.73
# 2    66.97       3.33
# 3     46.4        2.3
# 4    30.85       3.91

# %%
cities_df.to_csv("cities_fullframe.csv")
cities_df.head()
# Out:
#              City Cloudiness Country        Date Humidity      Lat     Long  \
# 0  saint-philippe         90      RE  1615615211       65 -21.3585  55.7679
# 1         ushuaia         75      AR  1615615214       93    -54.8    -68.3
# 2         ahipara         59      NZ  1615615216       85 -35.1667  173.167
# 3    saint-gilles          0      FR  1615615216       81  43.6766   4.4302
# 4            zima         93      RU  1615615216       96  53.9202  102.044
#
#   Max Temp Wind Speed
# 0     84.2      20.71
# 1       41      43.73
# 2    66.97       3.33
# 3     46.4        2.3
# 4    30.85       3.91

# %%
cities_df["Lat"]=pd.to_numeric(cities_df["Lat"])
cities_df["Max Temp"]=pd.to_numeric(cities_df["Max Temp"])
cities_df["Humidity"]=pd.to_numeric(cities_df["Humidity"])
cities_df["Wind Speed"]=pd.to_numeric(cities_df["Wind Speed"])
cities_df["Cloudiness"]=pd.to_numeric(cities_df["Cloudiness"])
ymax=cities_df["Max Temp"].max()+10
ymin=cities_df["Max Temp"].min()-10
xmax=cities_df["Lat"].max()+10
xmin=cities_df["Lat"].min()+10

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City latitude vs Max temperature {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.scatter(cities_df["Lat"], cities_df["Max Temp"],marker="o", alpha=.8,linewidths=1, color="teal", edgecolors='blue',label="Urban")

plt.grid()
plt.tight_layout()

plt.savefig("latitude_Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
ymax=100+10
ymin=cities_df["Humidity"].min()-5
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City Latitude vs. Humidity Plot {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(cities_df["Lat"], cities_df["Humidity"],marker="o", alpha=.6,linewidths=1, color="blue", edgecolors='black',label="Urban")

plt.grid()

plt.savefig("latitude_Humidty.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
ymax=cities_df["Cloudiness"].max()+10
ymin=cities_df["Cloudiness"].min()-5
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City Latitude vs. Cloudiness {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.scatter(cities_df["Lat"], cities_df["Cloudiness"],marker="o", alpha=.6,linewidths=1, color="blue", edgecolors='black',label="Urban")

plt.grid()

plt.savefig("latitude_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
ymax=cities_df["Wind Speed"].max()+10
ymin=cities_df["Wind Speed"].min()-5
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City Latitude vs. Wind Speed {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")

plt.scatter(cities_df["Lat"], cities_df["Wind Speed"],marker="o", alpha=.6,linewidths=1, color="blue", edgecolors='black',label="Urban")

plt.grid()


plt.savefig("latitude_Wind_Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_df = cities_df.loc[pd.to_numeric(cities_df["Lat"]).astype(float) > 0, :]
southern_df = cities_df.loc[pd.to_numeric(cities_df["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=northern_df['Lat']

y_values = northern_df['Max Temp']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.9005747679894786

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.43x + 82.47
# The r-squared is: 0.5423531231864076
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.27x + 57.8
# The r-squared is: 0.23981016229440066
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.32x + 81.34
# The r-squared is: 0.26207970612626946
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.41x + 34.57
# The r-squared is: 0.20791640553357435
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 1.07x + 68.19
# The r-squared is: 0.3943450457133364
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.07x + 6.96
# The r-squared is: 0.2121308497620894
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.17x + 3.69
# The r-squared is: -0.3750689191731731
# The regression does not display much of a correlation between the data sets.
